# %%
# import neccessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
# %matplotlib inline

# %%
# functions needed to study various behaviours

def readData(dirname, fileConditions):
    global attdata
    files = listdir(dirname)

    for f in files:
        if all(con in f for con in fileConditions):
            filesplit = f.split('_')
            # for every file from data folder read it, then extract neccessary values
            data = pd.read_csv(dirname + f, index_col=0)
            # convert all the results from [-1,1] to [0,1]
            data.replace([-1],[0], inplace=True)
            gamedata.loc[len(gamedata)] = [int(filesplit[1]), int(filesplit[3]), int(filesplit[5]), 
                                           int(filesplit[7]), int(filesplit[9]), 
                                           (2**float(filesplit[1])/int(filesplit[3])), data.sum().mean(), 
                                           # variance, normalized variance
                                           data.sum().var(), (data.sum().var() / int(filesplit[3])),
                                           # standard deviation
                                           np.std(data.sum())]
            attdata[f] = data.sum()

    attdata = pd.DataFrame(attdata)
    calculateHistory()
    
# plot attendance per rounds for various number of agents
def plotAtt(*agentConditions):
    # parse the input (divide number of agents from rest of the conditions
    # that are true for every number of agents)
    nAgentsConditions = []
    otherConditions = []
    for a in agentConditions:
        if 'N' in a:
            nAgentsConditions.append(a)
        else:
            otherConditions.append(a)
            
    for x in attdata.columns:
        if (all(j in x for j in otherConditions) and any(k in x for k in nAgentsConditions)):
            attdata[x][:50].plot(legend=True)
    
    plt.legend(loc='lower left')
    
# plot Alpha to normalize variance for all the runs
def plotAlphaToNormVar():
    alphaToNormVar = {}
    for x in range(len(gamedata)):
        if gamedata.alpha[x] in alphaToNormVar:
            alphaToNormVar[gamedata.alpha[x]].append(gamedata.normVar[x])
        else:
            alphaToNormVar[gamedata.alpha[x]] = [gamedata.normVar[x]]

    for x in alphaToNormVar.keys():
        alphaToNormVar[x] = sum(alphaToNormVar[x]) / len(alphaToNormVar[x])

    alphaToNormVar = pd.DataFrame({ 'alpha' : alphaToNormVar.keys(), 'normVar' : alphaToNormVar.values() })
    alphaToNormVar.plot(kind='scatter', x='alpha', y='normVar', loglog=True, legend=True)
    
def plotMemoryToStdDev():
    gamedata.plot(kind='scatter', x='M', y='stdDev')
    
def plotHistoryToProb(k, *args):
    histDict = {}
    # calculate history for all the games
    # calculateHistory()
    
    # args are conditions of the game to be read
    conditions = [a for a in args]
    for key in histori.keys():
        if all(j in key for j in conditions):
            for x in range(k, len(histori[key])-1):
                ckey = ''.join(str(a) for a in histori[key][x-k:x])
                ckey = str(int(ckey,2))
                if ckey not in histDict.keys():
                    histDict[ckey] = []
                histDict[ckey].append(histori[key][x])

    # after we have calculated the dictionary with
    # (key, value) = (history, decision list)
    # we have to calculate the probability about the decision
    # given a particular history
    if histDict:
        johnny = pd.DataFrame(columns=['memory', 'prob'])
        for j in histDict.keys():
            johnny.loc[len(johnny)] = [int(j), float(sum(histDict[j])) / len(histDict[j])]

        johnny.sort(columns='memory', inplace=True)
        johnny.plot(kind='bar', x='memory', y='prob')        
    
def calculateHistory():
    global histori
    for k in attdata.keys():
        filesplit = k.split('_')
        n = int(filesplit[3])
        histori[k] = [1 if x<=n/2 else 0 for x in attdata[k]] 
        
    histori = pd.DataFrame(histori)

# %%
# global variables that keep data for further study
gamedata = pd.DataFrame(columns=['M', 'N', 'S', 'rounds', 'run', 'alpha', 'attendance mean', 'variance', 'normVar', 'stdDev'])
attdata = {}
histori = {}

# global configuration
dirname = '../data/n101s2_04/'
# fileConditions = ['M_4', 'N_101', 'S_2']
fileConditions = []

# run the initial functions to read the data
readData(dirname, fileConditions)

# # calls to functions should look like this
# plotAtt('N_501', 'N_1001', 'run_19')
# plotAlphaToNormVar()
# plotMemoryToStdDev()
# plotHistoryToProb(4, 'M_4', 'N_1001', 'run_19')

# %%
gamedata.sort(columns='M')
# Out:
#       M    N  S rounds run       alpha attendance mean  variance    normVar  \
# 22    2  101  2  10000  12  0.03960396         51.5318  141.3369   1.399375
# 30    2  101  2  10000   7  0.03960396         50.3289   112.867   1.117495
# 35    2  101  2  10000   1  0.03960396         50.5491  165.0205   1.633866
# 43    2  101  2  10000   0  0.03960396         49.0836  102.9447   1.019255
# 51    2  101  2  10000  24  0.03960396         49.7113  170.7178   1.690275
# 99    2  101  2  10000   9  0.03960396          52.072  161.2365   1.596401
# 102   2  101  2  10000  15  0.03960396          50.698  151.3631   1.498645
# 109   2  101  2  10000  29  0.03960396         48.6913   106.201   1.051495
# 111   2  101  2  10000  21  0.03960396         50.1903   136.673   1.353198
# 134   2  101  2  10000  10  0.03960396         52.9682  131.6486   1.303451
# 140   2  101  2  10000   4  0.03960396         50.5699  119.6739    1.18489
# 145   2  101  2  10000   5  0.03960396         49.8201  113.1409   1.120206
# 146   2  101  2  10000  22  0.03960396         50.0565  80.33314  0.7953776
# 152   2  101  2  10000   6  0.03960396         50.0328  155.5701   1.540298
# 157   2  101  2  10000  25  0.03960396          48.505  115.2565   1.141153
# 160   2  101  2  10000  17  0.03960396         49.1757  112.7833   1.116666
# 177   2  101  2  10000  11  0.03960396          50.167  201.1738    1.99182
# 203   2  101  2  10000  26  0.03960396          49.376  105.4742   1.044299
# 229   2  101  2  10000  23  0.03960396         50.9231   126.492   1.252396
# 249   2  101  2  10000  13  0.03960396         49.3829  138.2925   1.369233
# 270   2  101  2  10000  27  0.03960396         51.2617  171.1919    1.69497
# 275   2  101  2  10000  19  0.03960396         51.0137  152.0873   1.505815
# 279   2  101  2  10000  20  0.03960396         49.7156  153.7065   1.521846
# 283   2  101  2  10000  18  0.03960396         49.1438  210.4534   2.083697
# 300   2  101  2  10000  31  0.03960396         51.0572  136.1733   1.348251
# 304   2  101  2  10000  16  0.03960396         49.4648  127.9702   1.267031
# 316   2  101  2  10000  30  0.03960396         51.6513  128.0717   1.268037
# 318   2  101  2  10000  14  0.03960396         50.5676   171.321   1.696247
# 339   2  101  2  10000   2  0.03960396          50.129  119.3881    1.18206
# 344   2  101  2  10000   3  0.03960396         48.7551  139.1262   1.377487
# ..   ..  ... ..    ...  ..         ...             ...       ...        ...
# 6    12  101  2  10000  24    40.55446         50.4359  24.49554  0.2425301
# 13   12  101  2  10000   4    40.55446          50.618   24.2875  0.2404703
# 37   12  101  2  10000  11    40.55446         50.4773  24.08549  0.2384702
# 42   12  101  2  10000  18    40.55446         50.5597  23.22196  0.2299204
# 57   12  101  2  10000  12    40.55446         50.5877  25.52326  0.2527056
# 69   12  101  2  10000  25    40.55446         50.6502  25.20616  0.2495659
# 103  12  101  2  10000   7    40.55446         50.5802  25.10388  0.2485533
# 104  12  101  2  10000  27    40.55446         50.5286  24.06139  0.2382316
# 110  12  101  2  10000   5    40.55446         50.5536  25.15464  0.2490559
# 125  12  101  2  10000  16    40.55446         50.5316  24.54486  0.2430184
# 137  12  101  2  10000  21    40.55446         50.4855  24.33402  0.2409309
# 151  12  101  2  10000   0    40.55446         50.4195  24.66419  0.2441999
# 167  12  101  2  10000   3    40.55446         50.4179  23.92625  0.2368936
# 175  12  101  2  10000  28    40.55446         50.6217  23.69096  0.2345639
# 189  12  101  2  10000  31    40.55446         50.4473  24.52748  0.2428463
# 197  12  101  2  10000   2    40.55446         50.5031  24.71946  0.2447472
# 209  12  101  2  10000  17    40.55446         50.5411  24.95761   0.247105
# 212  12  101  2  10000  19    40.55446         50.3399  24.77565  0.2453034
# 217  12  101  2  10000  14    40.55446         50.4331  24.53058   0.242877
# 222  12  101  2  10000   9    40.55446         50.4048  24.19096  0.2395144
# 228  12  101  2  10000  22    40.55446         50.5272  24.66933  0.2442508
# 230  12  101  2  10000   6    40.55446          50.418  23.87266   0.236363
# 235  12  101  2  10000  23    40.55446         50.5861  23.82377  0.2358789
# 251  12  101  2  10000   1    40.55446         50.4172  24.43799  0.2419603
# 255  12  101  2  10000  29    40.55446         50.4461  24.42474  0.2418291
# 272  12  101  2  10000  20    40.55446         50.6298  24.26358  0.2402334
# 299  12  101  2  10000  30    40.55446         50.5427   24.2074  0.2396772
# 328  12  101  2  10000  13    40.55446         50.4824  24.65096  0.2440689
# 329  12  101  2  10000  15    40.55446         50.5094  25.50466  0.2525214
# 340  12  101  2  10000  10    40.55446         50.7928  25.18979  0.2494038
#
#        stdDev
# 22   11.88793
# 30   10.62336
# 35   12.84539
# 43   10.14566
# 51   13.06525
# 99   12.69726
# 102  12.30236
# 109  10.30487
# 111  11.69014
# 134  11.47325
# 140  10.93901
# 145  10.63624
# 146  8.962428
# 152  12.47215
# 157  10.73522
# 160  10.61942
# 177  14.18287
# 203  10.26955
# 229  11.24631
# 249   11.7592
# 270  13.08338
# 275  12.33175
# 279  12.39722
# 283  14.50629
# 300  11.66875
# 304  11.31182
# 316  11.31631
# 318  13.08831
# 339  10.92594
# 344  11.79459
# ..        ...
# 6     4.94905
# 13   4.927989
# 37   4.907452
# 42   4.818676
# 57   5.051803
# 69   5.020323
# 103  5.010127
# 104  4.904996
# 110   5.01519
# 125  4.954029
# 137  4.932706
# 151  4.966057
# 167  4.891202
# 175  4.867092
# 189  4.952274
# 197  4.971618
# 209  4.995509
# 212  4.977265
# 217  4.952588
# 222  4.918184
# 228  4.966574
# 230  4.885722
# 235  4.880716
# 251  4.943232
# 255  4.941892
# 272  4.925561
# 299  4.919855
# 328  4.964725
# 329  5.049962
# 340  5.018692
#
# [352 rows x 10 columns]

# %%
plotAtt('M_10', 'N_101', 'run_0')

# %%
plotHistoryToProb(6,'M_5', 'N_101', 'run_0')

# %%
plotMemoryToStdDev()

# %%
plotAlphaToNormVar()
